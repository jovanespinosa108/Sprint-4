# %% [markdown]
# Esta es una recapitulación rápida de lo que has aprendido:
#
# En este capítulo, exploraste cómo mejorar tu conjunto de datos mediante la ingeniería de características:
#
# Creación de columnas nuevas: aprendiste varias formas de generar columnas nuevas a partir de los datos existentes, enriqueciendo tu conjunto de datos con características adicionales.
#
# Escritura de funciones personalizadas: dominaste cómo escribir tus propias funciones para gestionar necesidades de procesamiento específicas y las aplicaste a tus datos.
#
# Uso del método apply(): descubriste cómo sacar ventaja del método apply() para realizar transformaciones complejas y crear nuevas columnas basándote en criterios sofisticados.

# %%
# Creación de una columna nueva con base en datos existentes
df['total_sales'] = df['quantity'] * df['price']

# Aplicación de una función personalizada para calcular categorías
def post_code_and_address_to_territory_group(row):
    # Lógica personalizada para determinar el grupo de territorios
    pass

df['territory_group'] = df.apply(post_code_and_address_to_territory_group, axis=1)

# %% [markdown]
# Estas técnicas incrementarán de forma significativa tu capacidad de generar información valiosa a partir de tus datos. ¡Ahora prueba tu comprensión con los cuestionarios!
#
# Práctica guiada
#
# Pregunta
#
# Cuestionario 1
# ¿En qué consiste la ingeniería de características?
#
# Añadir nuevas características a un modelo de aprendizaje automático.
#
# - Crear nuevas variables a partir de las existentes.
#
# En el aprendizaje automático, el proceso de creación de nuevas columnas mediante el procesamiento de datos de las columnas originales del dataset se llama ingeniería de características. Las nuevas columnas tienen por objeto ayudar a revelar señales útiles del dataset a los algoritmos de aprendizaje automático, lo que mejora la calidad general del modelo.
#
# Implementar funciones en un producto basado en software.
#
# ¡Excelente trabajo!
#
# Pregunta
#
# Cuestionario 2
# ¿Qué transformación no es probable que forme parte de la ingeniería de características?
#
# Sumar todas las ventas de las diferentes regiones.
#
# Multiplicar la cantidad vendida por el precio.
#
# - Convertir las fechas de los strings en el tipo de datos datetime.
#
# Se trata de una transformación de tipo de datos y, por tanto, no es probable que ayude a mejorar la calidad del modelo. Extraer diferentes componentes temporales de estos valores como columnas separadas puede ser útil, y también puede considerarse como ingeniería de características.
#
# Copiar el año y el mes de una columna de tipo datetime a nuevas columnas separadas.
#
# ¡Tu comprensión del material es impresionante!
#
# Pregunta
#
# Cuestionario 3
# ¿Qué caso se consideraría el peor para la conversión al tipo category?
#
# Sabores de helado.
#
# - Números primos.
#
# Hay demasiados números primos (teóricamente un número infinito). Sería difícil encontrar escenarios en los que fuera necesario tratarlos como una categoría.
#
# Clases de medallas olímpicas.
#
# Nombres de los fabricantes de smartphones.
#
# ¡Tu comprensión del material es impresionante!
#
# Pregunta
#
# Cuestionario 4
# ¿Quieres ejecutar una función personalizada para calcular las categorías en función de los valores de la columna? ¿Qué función de pandas utilizarías?
#
# - apply()
#
# Esto nos permite aplicar una función personalizada a lo largo de un objeto Series o un eje del objeto DataFrame.
#
# astype()
#
# run()
#
# ¡Perfecto!
#
# Pregunta
#
# Cuestionario 5
# Quieres ejecutar una función personalizada llamada post_code_and_address_to_territory_group para calcular las categorías basadas en los valores de diferentes columnas. ¿Cómo llamarías a la función apply() para hacerlo?
#
# df.apply(post_code_and_address_to_territory_group, axis=0)
#
# - df.apply(post_code_and_address_to_territory_group, axis=1)
#
# ¡Correcto! Necesitamos establecer el parámetro axis a 1 si queremos que apply() pase los valores de fila de la función. Si hubiéramos puesto el parámetro axis a 0, apply() habría pasado los valores de la columna a la función.
#
# ¡Buen trabajo!
#
# Siguientes pasos
#
# En este capítulo construiste bases sólidas de la ingeniería de características con Pandas. Por ahora, ya puedes:
#
# - Crear columnas nuevas a partir de los datos existentes para mejorar tu conjunto de datos.
#
# - Presentar el tipo de datos category como forma de representar strings únicos con valores numéricos diferentes.
#
# - Escribir funciones personalizadas para gestionar necesidades de procesamiento específicas.
#
# - Aplicar el método apply() para realizar transformaciones de datos complejas.
#
# En el siguiente capítulo, incrementarás tus habilidades explorando técnicas avanzadas para agrupar y combinar datos. Aprenderás cómo utilizar la función groupby() para la agregación, a aprovechar las tablas dinámicas para el análisis de datos y a combinar datos de múltiples DataFrames mediante la concatenación y la fusión.
